# %% [markdown]
# # 01 — Data Inventory
#
# Load dataset and inspect structure.

# %%
import os
import pandas as pd

BASE = '/path/to/DAIC_WOZ'
print(os.listdir(BASE)[:10])

# %%
# Example: load a transcript
# transcript = pd.read_csv(f"{BASE}/extracted/492/492_TRANSCRIPT.csv", sep='\t')
# transcript.head()
